# %%
import pandas as pd

# %%
pd.read_csv('AllCompanyVN.csv')
# Out:
#      Symbol                                       Name Company cafef_exchange  \
# 0       24H                      CTCP QUẢNG CÁO TRỰC TUYẾN 24H            OTC
# 1       A32                                 CÔNG TY CỔ PHẦN 32          UPCOM
# 2       AAA                  CÔNG TY CỔ PHẦN NHỰA AN PHÁT XANH            HSX
# 3       AAC              CÔNG TY TNHH KIỂM TOÁN VÀ KẾ TOÁN AAC            NaN
# 4       AAM                    CÔNG TY CỔ PHẦN THỦY SẢN MEKONG            HSX
# ...     ...                                                ...            ...
# 2023    YBM     CÔNG TY CỔ PHẦN KHOÁNG SẢN CÔNG NGHIỆP YÊN BÁI            HSX
# 2024    YEG                     CÔNG TY CỔ PHẦN TẬP ĐOÀN YEAH1            HSX
# 2025    YRC                  CÔNG TY CỔ PHẦN ĐƯỜNG SẮT YÊN LÀO          UPCOM
# 2026    YSC                     CÔNG TY CỔ PHẦN HAPACO YÊN SƠN            HNX
# 2027    YTC  CÔNG TY CỔ PHẦN XUẤT NHẬP KHẨU Y TẾ THÀNH PHỐ ...          UPCOM
#
# ...

# %%
df = pd.read_csv('Data_lake/save_VSD.csv')

# %%
df['check'] = df['STT'].diff()

# %%
df[df.check != 1]
# Out:
#      STT       Mã ISIN Mã chứng khoán  \
# 0      1  VN000000A329            A32
# 10     1  VN000000A329            A32
# 970  951  VN0CMBB22029       CMBB2202
# 980  971  VN0CMSN20063       CMSN2006
#
#                                    Tên tổ chức đăng ký  check
# 0                                   Công ty cổ phần 32    NaN
# 10                                  Công ty cổ phần 32   -9.0
# 970               Công ty cổ phần Chứng khoán VnDirect   -9.0
# 980  Công ty Cổ phần Chứng khoán Thành phố Hồ Chí Minh   11.0
